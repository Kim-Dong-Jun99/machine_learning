# %%
import numpy as np
import matplotlib.pyplot as plt
temp = np.exp(np.power(-(0.1*1), 2))
print(temp)
# Out:
# 1.010050167084168

# %%
temp = np.exp(-0.1*1)
print(temp)
# Out:
# 0.9048374180359595

# %%
x = np.array([-2,-1,0,1,2])
c = [1,1,0,1,1]
new_f2 = np.array([0.202, 0.407, 0.67, 0.905, 1])
new_f1 = np.array([0.905, 1, 0.905, 0.67, 0.407])
plt.xlabel("new feature 1")
plt.ylabel("new feature 2")
plt.title("Scatter plot of new feature")
plt.scatter(new_f1,new_f2, c=c)
